# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Nonstate_v24_1.csv")

# %%
df.head()
# Out:
#    conflict_id  dyad_id  org side_a_name side_a_name_fulltext  \
# 0         9488    10098    3      Fulani               Fulani
# 1         9637    10247    3    Konianke             Konianke
# 2         9654    10264    3        Arab                 Arab
# 3         9668    10278    3        Arab                 Arab
# 4         9668    10278    3        Arab                 Arab
#
#   side_a_name_mothertongue  side_a_id side_a_components side_a_2nd  \
# 0                   Fulani        607               NaN        NaN
# 1                 Konianke       1713               NaN        NaN
# 2                     Arab       1012               NaN        NaN
# 3                     Arab       1012               NaN        NaN
# 4                     Arab       1012               NaN        NaN
#
#    gwno_a_2nd  ... ep_end_date ep_end_prec  year  best_fatality_estimate  \
# 0         NaN  ...  2021-06-09         1.0  2021                      41
# ...

# %%
df.columns = df.columns.str.strip()
somalia_df = df[df['location'] == 'Somalia']

# %%
print(somalia_df)
# Out:
#       conflict_id  dyad_id  org  \
# 42          10938    11548    1
# 43          10938    11548    1
# 369         14072    15201    3
# 370         14072    15201    3
# 371         14073    15202    1
# ...           ...      ...  ...
# 1513         4944     5554    1
# 1516         4947     5557    1
# 1538         4957     5567    3
# 1539         4958     5568    1
# 1541         4961     5571    1
#
#                                           side_a_name  \
# 42                         SSC-Khatumo Administration
# 43                         SSC-Khatumo Administration
# 369   Bahararsame subclan of Dhulbahante clan (Darod)
# 370   Bahararsame subclan of Dhulbahante clan (Darod)
# 371                                        Al-Shabaab
# ...                                               ...
# 1513                Mujahideen in the Golis Mountains
# 1516                             Ahlu Sunna Waljamaca
# 1538                              Abgal clan (Hawiye)
# ...

# %%
somalia_df['start_date2'] = pd.to_datetime(somalia_df['start_date2'], errors='coerce')
# Out:
# C:\Users\yumna\AppData\Local\Temp\ipykernel_15896\317892645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   somalia_df['start_date2'] = pd.to_datetime(somalia_df['start_date2'], errors='coerce')

# %%
somalia_df = somalia_df.sort_values('start_date2')

# %%
plt.figure(figsize=(48,24))
plt.plot(somalia_df['start_date2'], somalia_df['high_fatality_estimate'], marker='o', linestyle='-',color='red')
plt.title("casualties in Somalia 1990-2024",fontsize=30)
plt.xlabel("Year",fontsize=30)
plt.ylabel("Casualties", fontsize=30)
plt.grid(True)
plt.tight_layout()
plt.show()
